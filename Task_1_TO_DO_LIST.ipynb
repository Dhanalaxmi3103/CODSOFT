# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanalaxmi3103/Codsoft/blob/Python/Task_1_TO_DO_LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def show_options():
 print("\n")
 print("~~~~~~~~TO_DO LIST~~~~~~~~~~")
 print("1.Add Task")
 print("2.Delete a Task")
 print("3.Delete all Tasks")
 print("4.Edit a Task")
 print("5.View tasks")
 print("6.Exit")

#creating an empty list
taskList=[]
# defining funcxtion to adding task into list
def addingTask():
  wish= input("Enter your task to do:")
  taskList.append(wish)
  print("Your task added to LIST")
#defining function to delete a task from list
def deletingTask():
  if len(taskList)==0:
    print("No tasks to delete in list")
  else:
    print("Available tasks")
    for index,wish in enumerate(taskList):
      print(f"{index+1}.{wish}")
      option1=int(input("enter the number of task to be deleted="))
      if option1>0 and option1<=len(taskList):
       del taskList[option1-1]
       print("Task deleted")
      else:
       print("Invalid option")

#defining function to delete all tasks from list
def deleteAll():
  taskList.clear()
  print("All tasks deleted")

# defini function to view list of tash
def viewTask():
  if not taskList:
    print("No tasks to view")
  else:
    print("*****TASKS******")
    for index,wish in enumerate(taskList):
      print(f"{index+1}.{wish}")


# defining function to edit a task from list
def editingTask():
  if len(taskList)==0:
    print("No trask is available to edit in list")
  else:
    print("Available tasks")
    for index,wish in enumerate(taskList):
      print(f"{index+1}.{wish}")
      option2=int(input("enter the number of task to be edited="))
      if option2>0 and option2<=len(taskList):
             new_wish=input("Enter the new task")
             taskList[option2-1]=new_wish
             print("Task edited")
      else:
             print("Invalid option")
      exit()


while True:
  show_options()
  option=int(input("Enter your option:"))

  if option==1:
   addingTask()
  elif option==2:
    deletingTask()
  elif option==3:
    deleteAll()
  elif option==4:
    editingTask()
  elif option==5:
    viewTask()
  elif option==6:
    print("exciting from task")
    break
  else:
    print("Invalid option")
# Out:
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:1
# Enter your task to do:coding
# Your task added to LIST
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:1
# Enter your task to do:reading
# Your task added to LIST
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:4
# Available tasks
# 1.coding
# enter the number of task to be edited=2
# Enter the new taskreading book
# Task edited
# 2.reading book
# enter the number of task to be edited=6
# Invalid option
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:5
# *****TASKS******
# 1.coding
# 2.reading book
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:2
# Available tasks
# 1.coding
# enter the number of task to be deleted=2
# Task deleted
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:5
# *****TASKS******
# 1.coding
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:3
# All tasks deleted
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:5
# No tasks to view
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:1
# Enter your task to do:reading
# Your task added to LIST
#
#
# ~~~~~~~~TO_DO LIST~~~~~~~~~~
# 1.Add Task
# 2.Delete a Task
# 3.Delete all Tasks
# 4.Edit a Task
# 5.View tasks
# 6.Exit
# Enter your option:6
# exciting from task
